# %%
import pandas as pd
import numpy as np
from scraper import GameLogs

# %%
gamelogs = GameLogs("Stephen Curry")
dat = gamelogs.fetch_data()

# %%
dat
# Out:
#     Rk     G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  \
# 0    1   1.0  2024-10-23  36-223  GSW          @  POR    W (+36)
# 1    2   2.0  2024-10-25  36-225  GSW          @  UTA    W (+41)
# 2    3   3.0  2024-10-27  36-227  GSW        NaN  LAC     L (-8)
# 3    4   NaN  2024-10-29  36-229  GSW        NaN  NOP    W (+18)
# 4    5   NaN  2024-10-30  36-230  GSW        NaN  NOP    W (+15)
# 5    6   NaN  2024-11-02  36-233  GSW          @  HOU     W (+6)
# 6    7   4.0  2024-11-04  36-235  GSW          @  WAS    W (+13)
# 7    8   5.0  2024-11-06  36-237  GSW          @  BOS     W (+6)
# 8    9   6.0  2024-11-08  36-239  GSW          @  CLE    L (-19)
# 9   10   7.0  2024-11-10  36-241  GSW          @  OKC    W (+11)
# 10  11   8.0  2024-11-12  36-243  GSW        NaN  DAL     W (+3)
# 11  12   9.0  2024-11-15  36-246  GSW        NaN  MEM     W (+5)
# 12  13  10.0  2024-11-18  36-249  GSW          @  LAC     L (-3)
# ...
